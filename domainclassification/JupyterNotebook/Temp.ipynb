# %%
# hosting services found in dataset
hostingProvidersDataset = ['000webhostapp.com', 'esy.es','16mb.com', 'at.ua', '890.com', '96.lt', 'tripod.com', 'sitey.me', 'my1.ru', 'clan.su', 'weebly.com', '5gbfree.com',
                        'blogspot.ca', 'blogspot.com', 'blogspot.de', 'blogspot.com.br', 'blogspot.it', 'blogspot.com.tr', 'blogspot.co.at', 'blogspot.com.es', 'blogspot.com.ar',
                        'blogspot.be', 'blogspot.co.il', 'blogspot.ae', 'ucoz.ro', 'ucoz.pl', 'ucoz.site', 'blogspot.com.tr', 'site44.com', 'wapka.me', 'wapka.mobi', 'yola.com',
                        'me.la', 'cloudns.net', 'cloudns.asia', 'page.tl', 'droppages.com', 'tr.gg', 'webydo.com', 'webservis.ru', 'hebergratuit.net', 'hebergratuit.com', 'es.tl', 'livecity.me',
                        'strikingly.com', 'cuccfree.com', 'ezyro.com', '260mb.net', 'blogspot.ru', 'blogspot.co.nz', 'paperform.co']

# top 10,000 hosting services from alexa that match in our dataset
hostingProvidersAlexa = ['wordpress.com', 'google.com', 'amazonaws.com', 'secureserver.net', 'weebly.com', 'jimdo.com', 'hostgater.com',
                    'bluehost.com', 'herokuapp.com', 'ipage.com', 'home.pl', 'wapka.me', 'justhost.com', 'arvixe.com', 'angelfire.com',
                    'webnode.com', 'blogcu.com', 'websitewelcome.com', 'rhcloud.com']

# top 500 from hostingkingdom
topHostingProviders = ['hostgator.com', 'godaddy.com', 'bluehost.com', 'ipage.com', 'webhostingtalk.com', 'inmotionhosting.com',
 'softlayer.com', 'reverbnation.com', 'homestead.com', 'site5.com', 'linode.com', 'fatcow.com', 'dreamhost.com',
 'liquidweb.com', 'web.com', 'he.net', 'ixwebhosting.com', 'rackspace.com', 'nexcess.net', 'netfirms.com',
 'siteground.com', 'ipower.com', 'moonfruit.com', 'myhosting.com', 'freewebs.com', 'fasthosts.co.uk',
 'interserver.net', 'hostdime.com', 'pair.com', 'lunarpages.com', 'names.co.uk', 'reverbnation.com',
 'liquidweb.com', 'ixwebhosting.com', 'interserver.net', 'pair.com', 'lunarpages.com', 'tripod.lycos.com',
 'hivelocity.net', 'doteasy.com', 'eukhost.com', 'datarealm.com', 'intermedia.net', 'somee.com', 'dotster.com',
 'web4africa.net', 'powweb.com', 'westhost.com', 'x10hosting.com', 'eteamz.com', 'webhostingstuff.com',
 'hypermart.net', 'verio.com', 'tigertech.net', 'webhostingbuzz.com', 'jaguarpc.com', 'globat.com',
 'atlantic.net', 'ewebguru.com', 'tierra.net', 'yellowpipe.com', 'hostmysite.com', 'discountasp.net',
 'aplus.net', 'netatlantic.com', 'hostforweb.com', 'netelligent.ca', 'omnis.com', 'rimuhosting.com',
 'hostsearch.com', 'rosehosting.com', 'tunescoop.com', 'freeservers.com', 'hostdepartment.com', 'zerolag.com',
 'hosting.com', '50megs.com', 'hostica.com', 'myfamily.com', 'hostbaby.com', 'netmagicsolutions.com',
 'internap.com', 'bounceweb.com', 'reliablehosting.com', 'ndchost.com', 'serverintellect.com', 'easycgi.com',
 'bizland.com', 'peer1.net', 'canadianwebhosting.com', 'ispserver.com', 'apthost.com', 'webspawner.com',
 'accuwebhosting.com', 'hostingdiscussion.com', '20m.com', 'eapps.com', 'networxhosting.com', 'xlhost.com',
 'sitelutions.com', 'netnation.com', 'storminternet.co.uk', '3essentials.com', '0catch.com', 'streamline.net',
 'appliedi.net', 'thewebhostingdir.com', 'infinitetech.eu', 'tindeck.com', 'staminus.net',
 'windstreambusiness.com', 'orcsweb.com', 'freewebspace.com', 'nettigritty.com', 'uk-cheapest.co.uk',
 'jodohost.com', 'inetu.net', 'totalchoicehosting.com', 'webhostchat.co.uk', 'free-webhosts.com', 'bigbiz.com',
 'futurequest.net', 'laughingsquid.us', 'datapipe.com', 'webmasters.com', 'cyberwurx.com', 'hostrocket.com',
 'bravepages.com', 'm3server.com', 'haisoft.net', 't35.com', '24shells.net', 'readyhosting.com', 'ace-host.net',
 'terranetwork.net', 'hotwebhostingtalk.com', 'servik.com', 'i2k2.com', 'auseverything.com.au', 'modwest.com',
 'lexiconn.com', 'layershift.com', 'prohosting.com', '101sitehosting.com', 'baremetal.com', 'tierpoint.com',
 'ait.com', 'netwood.net', 'hostsg.com', 'bluegenesis.com', 'cervalis.com', 'gearhost.com', 'smartyhost.com.au',
 'peak10.com', 'iniz.com', 'phpwebhosting.com', 'onlinetech.com', 'webcs.com', 'ilisys.com.au', 'xtraorbit.com',
 'flawebworks.com', 'findmyhost.com', 'kuwaitnet.net', 'cnchost.com', 'unitedhosting.co.uk', 'jumpline.com',
 'xilo.net', 'nearlyfreespeech.net', 'aspnix.com', 'webnet77.com', 'biz.ly', 'aussiehq.com.au', 'fpweb.net',
 'forums.totalchoicehosting.com', 'hostnexus.com', 'acunett.com', 'avahost.net', 'webhost.pro', 'infosaic.com',
 'fast2host.com', 'nationalnet.com', 'webvisions.com', 'hostingpost.com', 'seekdotnet.com', 'jabry.net',
 'lfchosting.com', 'nq.pl', 'alterlinks.com', 'webstarindia.com', 'kattare.com', 'ochosting.com',
 'onyxservers.com', 'viawest.com', '34sp.com', 'telecitygroup.com', 'webhostingreviews.com',
 'hosting.digiweb.ie', 'ibuilt.net', 'ukhost4u.com', 'ehost.com', '800hosting.com', 'orgsites.com',
 'digiweb.co.nz', 'webecs.com', 'rackforce.com', '2mhost.com', 'cybercon.com', 'server101.com', 'visn.co.uk',
 'm6.net', 'onenetwork.net', 'b2netsolutions.com', 'vwcom.net', 'edgewebhosting.net', 'eboundhost.com',
 'freehomepage.com', '2020media.com', 'your-site.com', 'cartika.com', 'icuk.net', 'downtownhost.com',
 'servercentral.com', 'logicworks.net', 'bluedomino.com', 'zoomfree.com', 'hostinguk.net', 'alentus.com',
 'thewebpower.com', 'hostingmetro.com', 'netcetera.co.uk', 'mystarpoint.com', 'thehostgroup.com', '7host.com',
 'infoquest.com', 'bizhosting.com', 'ukwebsolutionsdirect.co.uk', 'websitesource.com', 'spunkyworld.com',
 'catalyst2.com', 'cfdynamics.com', 'webnethosting.net', 'lonex.com', 'wowrack.com', 'webhosting.net',
 'dynamic.com', 'hostmatters.com', 'synapseglobal.com', 'hkhosting.com', 'xeran.com', 'canaca.com',
 'netministries.org', 'aldenhosting.com', 'webbase.co.nz', 'hostbreak.com', 'clockwatchers.com', 'jtlnet.com',
 'webhostmagazine.com', 'webhsp.com', 'hostingcatalog.com', 'vervehosting.com', 'node4.co.uk', 'voxdomains.com',
 'hostdepot.com', 'fluidhosting.com', 'camelot-hosting.com', 'handsonwebhosting.com', 'alonetone.com',
 'hostcolor.com', 'pakhost.com', 'hostm.com', 'nyi.net', 'christianwebhost.com', 'lanlogic.com',
 'yorkukhosting.com', 'bpweb.net', 'olm.net', 'efree2net.com', 'calpop.com', 'aspwebhosting.com.au',
 'successfulhosting.com', 'webkeepers.com', 'hostopia.com', 'webii.net', '1colony.com', 'donhost.co.uk',
 'elief.com', 'canhost.ca', 'ez-web-hosting.com', 'fluidata.co.uk', 'alwayswebhosting.com', 'mainehost.com',
 'dewahost.com', 'apollohosting.com', 'clickhost.com', 'imhosted.com', 'tweakedhosting.com', 'axishost.com',
 'weberz.com', 'hostvoice.com', 'wirenine.com', 'onewebhosting.com', 'bookandhost.com', 'ourinternet.us',
 'hostduplex.com', 'blacksun.ca', 'pipeten.com', 'dynamichosting.biz', 'wiserhosting.com',
 'visionwebhosting.net', 'unlimited-space.com', 'lowesthosting.com', 'dominionhosting.com',
 'saeverything.co.za', 'triple8.net', 'powersurge.net', 'intaserve.com', 'webzpro.com', 'meccahosting.com',
 'voxel.net', 'mirahost.com', 'hostindex.com', 'gsp.com', '100bestfreewebspace.com', 'catholic-church.org',
 'theonestopwebsiteshop.com', 'simplyhosting.net', 'stormwire.com', 'z-host.com', 'hagenhosting.com',
 'icestorm.com', 'identitywebhost.com', 'simplewebhosting.co.uk', 'bluewho.com', 'simplywebhosting.com',
 'worldbreak.com', 'allcheaphosting.com', 'domainhost.com', 'aalphanet.com', 'hosting4less.com',
 'elysiumgates.com', 'atomhost.com', '00server.com', 'ihostnetworks.com', 'serverside.net',
 '1dollarhosting.com', 'zyworld.com', 'fateback.com', 'infuseweb.com', 'cybrhost.com', 'sandwich.net',
 'aspwebhosting.com', 'domainavenue.com', 'resellerchoice.com', 'openvz.io', 'zipservers.com', 'boomp3.com',
 'zenutech.com', 'graffiti.net', 'internetconnection.net', 'activehost.com', 'wtv-zone.com', 'enterhost.com',
 'internetplanners.com', 'webhero.com', 'rapidservers.net', 'titaninternet.co.uk', 'webserve.ca', 'fido.net',
 'asp-host.co.uk', 'dynamicnet.net', 'hostignition.com', 'virtualempire.com', 'volico.com', 'artmotion.eu',
 'tollon.net', 'plexicomm.net', 'vs3.net', 'transparent-tech.com', 'vindia.net', 'bitera.com',
 'floridawebcrafters.com', 'interferenza.net', 'hostmds.com', 'webnow.co.za', 'witnesstoday.org',
 'hostmydomainnow.com', 'prominic.net', 'cali.co.uk', 'amhosting.com', 'oscura.co.uk', 'va.com.au',
 'comparewebhosts.com', 'ibiscushosting.com', 'atlashosting.com', 'beza.net', 'webfusion.co.uk',
 'dotnetpark.com', 'dotservant.com', 'hostings.com', 'infocrossing.com', 'netwave.pl', 'hostedfx.com',
 'sisna.com', 'webhosting.devshed.com', 'webwizards.net', 'mmoguildsites.com', 'x-mail.net',
 'activewebhosting.com', 'extreme-hosting.net', 'emwd.com', 'bizhostnet.com', 'exai.com', 'aqhost.com',
 'insiderhosting.com', 'prowebhost.co.uk', 'sitepalace.com', 'epidirect.com', 'ratemyhost.com', '1steasy.com',
 'stormweb.ca', 'hostpc.com', 'ez2ba.com', 'drundo.com', 'active-server.com', 'blackfoot.co.uk',
 'trkhosting.com', 'aryahosting.com', 'websecurestores.com', 'kznhost.com', 'apisnetworks.com',
 'dargalsolutions.com', 'localweb.com', '8.to', 'hostony.com', 'infinology.com', '1sthostweb.com',
 'digipark.com', 'metawerx.com.au', '724hosting.com', 'jcle.net', 'hostproof.com', 'hostroute.com',
 'tooniehosting.ca', 'entryhost.com', 'w3media.net', 'tvcnet.com', 'primetap.com', 'isqsolutions.com',
 'kiwihosting.net.nz', 'superb.net', 'mumbaihosting.com', 'zid.com', 'active-venture.com', 'brinkster.com',
 'sozohosting.com', 'iperweb.com', 'thinkhost.com', 'wolfweb.com.au', 'abimco.net', 'whitedoggreenfrog.com',
 'netfronts.com', 'adisol.com', 'smallbusiness.yahoo.com', 'tek.net', 'newbiesite.com', 'conexim.com.au',
 'iwfhosting.net', 'twsc.biz', 'cqhost.com', 'amerihost.com', 'xehost.net', '2globalmart.com', 'fawm.com',
 'finalhost.com', 'datapacket.net', 'wizard.ca', 'cyberax.net', 'serverrack.net', 'newmediacanada.com',
 'purplecat.net', 'xsserver.eu', 'friendpages.com', 'hostofspirits.com', 'zarcrom.com', 'flosoft.biz',
 'dzite.com', 'powerfulhosting.com', 'hotlinks.co.uk', 'kiwiwebhost.co.nz', 'spidersitebuilder.com',
 'datahive.ca', 'idig.net', 'clansitemanager.com', 'x9internet.com', 'knowtechnology.net', 'yourwebpro.com',
 'starenterprise.com', 'ilogichosting.com', 'connect.com.my']

# %%
hosting_providers = set(hostingProvidersDataset).union(set(hostingProvidersAlexa))
hosting_providers = hosting_providers.union(set(topHostingProviders))
print(hosting_providers)
print(len(hosting_providers))
# Out:
# {'alentus.com', 'web.com', 'smallbusiness.yahoo.com', 'rackforce.com', 'webhero.com', 'thewebhostingdir.com', 'elief.com', 'cali.co.uk', 'ucoz.pl', 'serverintellect.com', 'rosehosting.com', 'totalchoicehosting.com', 'digipark.com', 'bizland.com', 'iwfhosting.net', 'justhost.com', 'hosting4less.com', 'wapka.me', 'webnode.com', 'hosting.com', 'onlinetech.com', 'webservis.ru', 'ez2ba.com', 'knowtechnology.net', 'hostindex.com', 'freewebspace.com', 'webecs.com', 'hostmydomainnow.com', 'artmotion.eu', 'webmasters.com', 'phpwebhosting.com', 'futurequest.net', 'amhosting.com', 'wiserhosting.com', 'netelligent.ca', 'clockwatchers.com', 'kattare.com', 'openvz.io', 'eukhost.com', 'homestead.com', 'moonfruit.com', 'linode.com', 'webkeepers.com', 'aalphanet.com', 'cyberax.net', '000webhostapp.com', 'wapka.mobi', 'bitera.com', 'sandwich.net', 'webhostingreviews.com', 'bounceweb.com', 'telecitygroup.com', 'zyworld.com', 'enterhost.com', 'epidirect.com', 'wolfweb.com.au', 'tvcnet.com', 'aldenhostin
# ...

# %%
from pprint import pprint
# save trees
with open("hosting_providers", 'w', encoding="utf-8") as fout:
    pprint(hosting_providers, fout)
